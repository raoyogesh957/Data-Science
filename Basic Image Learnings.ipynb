# %%
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np
from tensorflow.keras.preprocessing import image
os.getcwd()
from tensorflow.keras.preprocessing.image import ImageDataGenerator
path='c:\\Users\\Yogesh Yadav\\OneDrive\\Desktop\\DS\\Python Learnings\\Image ML Project\\Virat'

# %%
a=[]
for i in os.listdir(path):
    a.append(i)
print(len(a))
# Out:
# 659

# %% [markdown]
# # Using TensorFlow

# %%
a=image.load_img(b)
a
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=154x140>

# %% [markdown]
# # PLT

# %%
b=path+'\\3.jpg'
img=np.array(cv2.imread(b))
img=img/255
plt.imshow(img,cmap=plt.cm.binary)
plt.show()

# %%
plt.figure(figsize=(16,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    img=np.array(cv2.imread(path+'\\'+a[i]))
    img=img/255
    plt.imshow(img,cmap=plt.cm.binary)

# %%
path
# Out:
# 'c:\\Users\\Yogesh Yadav\\OneDrive\\Desktop\\DS\\Python Learnings\\Image ML Project\\Virat'

# %%
p='c:\\Users\\Yogesh Yadav\\OneDrive\\Desktop\\DS\\Python Learnings\\Image ML Project\\'
train=ImageDataGenerator(rescale=1/255)
data=train.flow_from_directory(p,target_size=(255,255),batch_size=1,shuffle=False)
# Out:
# Found 799 images belonging to 2 classes.

# %%
data.class_indices
# Out:
# {'Roger Federar': 0, 'Virat': 1}

# %%
plt.matshow(data[0][0][0])

# %%
sorted(data.class_indices.keys(),key=lambda x:x[0])[data.classes[0]]
# Out:
# 'Roger Federar'

# %%
plt.matshow(data[0][0][0])

# %%
# Out:
# (255, 255, 3)
