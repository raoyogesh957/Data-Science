# %%
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np
from tensorflow.keras.preprocessing import image
os.getcwd()
from tensorflow.keras.preprocessing.image import ImageDataGenerator
path='c:\\Users\\Yogesh Yadav\\OneDrive\\Desktop\\DS\\Python Learnings\\Image ML Project\\Virat'

# %%
img=cv2.imread(path+'\\660.jpg')
img.shape
# Out:
# (768, 1024, 3)

# %%
plt.matshow(img)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (768, 1024)

# %%
plt.imshow(gray)

# %%
plt.imshow(gray,cmap='gray')

# %% [markdown]
# # Cascade Open CV - Documentation

# %% [markdown]
# # Face and Eyes detection

# %%
face_cascade=cv2.CascadeClassifier('./HaarCascade/haarcascade_frontalface_default.xml')
eye_cascade=cv2.CascadeClassifier('./HaarCascade/haarcascade_eye.xml')

faces=face_cascade.detectMultiScale(gray,1.1,2)
faces
# Out:
# array([[294, 203, 409, 409],
#        [611, 668,  56,  56],
#        [836,  39,  81,  81]])

# %%
face=faces[0]
(x,y,w,h)=face

# %%
im=cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),1)
plt.imshow(im)

# %%
cv2.destroyAllWindows()

for (x,y,w,h) in faces[:]:
    face_img=cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray=gray[y:y+h,x:x+w]
    roi_color=face_img[y:y+h,x:x+w] 
    eyes=eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2) 
plt.figure()
plt.imshow(face_img,cmap='gray')
plt.show()

# %%
def two_eyes(img):
    face_cascade=cv2.CascadeClassifier('./HaarCascade/haarcascade_frontalface_default.xml')
    eye_cascade=cv2.CascadeClassifier('./HaarCascade/haarcascade_eye.xml')

    faces=face_cascade.detectMultiScale(img,1.3,5)
    cv2.destroyAllWindows()
    try:
        for (x,y,w,h) in faces[:]:
            face_img=cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            roi_gray=gray[y:y+h,x:x+w]
            roi_color=face_img[y:y+h,x:x+w] 
            eyes=eye_cascade.detectMultiScale(roi_color)
            # for (ex,ey,ew,eh) in eyes:
            #     cv2.rectangle(face_img,(ex,ey),(ex+ew,ey+eh),(0,255,0),2) 

            if len(eyes)>=2:
                return roi_color 
    except:
        pass

# %%
img=cv2.imread(path+'\\660.jpg')
plt.matshow(two_eyes(img))

# %%
img=cv2.imread(path+'\\6.jpg')
plt.matshow(two_eyes(img))

# %%
i=1
c=1
plt.figure(figsize=(16,9))
while True :
    img=cv2.imread(path+'\\{}.jpg'.format(i))
    try:
        #img1=two_eyes(img)
        plt.subplot(5,5,c)
        plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2GRAY),cmap='gray')
        c+=1
    except:
        pass
    i+=1
    if c==26:
        break
plt.show()

# %%
i=1
c=1
plt.figure(figsize=(16,9))
while True :
    img=cv2.imread(path+'\\{}.jpg'.format(i))
    try:
        img1=two_eyes(img)
        plt.subplot(5,5,c)
        plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY),cmap='gray')
        c+=1
    except:
        pass
    i+=1
    if c==26:
        break
plt.show()

# %%
import os

path='./Dataset/'
path_cropped='./Dataset/Cropped'

# %%
a=os.getcwd()
a
img_dirs=[]
