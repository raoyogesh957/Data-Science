# %%
import bs4
import requests
import pandas as pd
import urllib

# %%
url="https://www.amazon.in/s?k=phones&crid=3L1HSLKP2KMYH&sprefix=phones%2Caps%2C260&ref=nb_sb_noss_1"

# %%
webpage=requests.get(url,headers=({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}))
webpage
# Out:
# <Response [200]>

# %%
soup=bs4.BeautifulSoup(webpage.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
abc=soup.find('div',{'class':'sg-col-inner'})
abc
# Out:
# <div class="sg-col-inner">
# <div class="a-section a-spacing-small a-spacing-top-small">
# <span>1-16 of over 5,000 results for</span><span> </span><span class="a-color-state a-text-bold">"phones"</span>
# </div>
# </div>

# %%
for i in soup.find_all(class_='a-size-medium a-color-base a-text-normal'):
    print(i.text)
# Out:
# Oppo F23 5G (Bold Gold, 8GB RAM, 256GB Storage) | 5000 mAh Battery with 67W SUPERVOOC Charger | 64MP Rear Triple AI Camera with Microlens | 6.72" FHD+ 120Hz Display | with Offers
# Redmi 12C (Royal Blue, 4GB RAM, 64GB Storage) | High Performance Mediatek Helio G85 | Big 17cm(6.71) HD+ Display with 5000mAh(typ) Battery with 10W Charger in-Box
# Samsung Galaxy M04 Dark Blue, 4GB RAM, 128GB Storage | Upto 8GB RAM with RAM Plus | MediaTek Helio P35 Octa-core Processor | 5000 mAh Battery | 13MP Dual Camera
# Redmi Note 12 5G Mystique Blue 4GB RAM 128GB ROM | 1st Phone with 120Hz Super AMOLED and Snapdragon® 4 Gen 1 | 48MP AI Triple Camera
# Nokia C12 Android 12 (Go Edition) Smartphone, All-Day Battery, 4GB RAM (2GB RAM + 2GB Virtual RAM) + 64GB Capacity | Light Mint
# Samsung Galaxy M04 Light Green, 4GB RAM, 64GB Storage | Upto 8GB RAM with RAM Plus | MediaTek Helio P35 Octa-core Processor | 5000 mAh Battery | 13MP Dual Camera
# ...

# %%
for i in soup.find_all(class_='a-price-whole'):
    print(i.text)
# Out:
# 1,199.
# 1,759.
# 899.
# 24,998
# 8,999
# 9,499
# 17,999
# 5,699
# 18,499
# 8,499
# 5,699
# 284
# 299
# 358
# 284.
# 8,499
# 21,999
# 12,999
# 10,999
# 4,499
# 6,499
# 6,299
# 8,999
# 10,999
# 18,499
# 8,499
# 7,999
# 5,699
# 34,999
# 5,699
# 6,499
# 6,799

# %%
for i in soup.find_all('a'):
    print(i.get('href'))
# Out:
# None
# None
# /ref=nav_logo
# None
# /customer-preferences/edit?ie=UTF8&preferencesReturnUrl=%2F&ref_=topnav_lang
# https://www.amazon.in/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https%3A%2F%2Fwww.amazon.in%2Fs%2F%3F_encoding%3DUTF8%26crid%3D3L1HSLKP2KMYH%26k%3Dphones%26ref%3Dnb_sb_noss_1%26sprefix%3Dphones%252Caps%252C260%26ref_%3Dnav_ya_signin&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.assoc_handle=inflex&openid.mode=checkid_setup&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&
# /gp/css/order-history?ref_=nav_orders_first
# https://www.amazon.in/gp/cart/view.html?ref_=nav_cart
# /gp/site-directory?ref_=nav_em_js_disabled
# /minitv?ref_=nav_avod_desktop_topnav
# /b/32702023031?node=32702023031&ld=AZINSOANavDesktop_T3&ref_=nav_cs_sell_T3
# /gp/bestsellers/?ref_=nav_cs_bestsellers
# /deals?ref_=nav_cs_gb
# ...

# %%
for i in soup.find_all(class_='a-section aok-relative s-image-fixed-height'):
    a=i.find('img')
    b=a.get('src')
    print(b)
# Out:
# https://m.media-amazon.com/images/I/81t-iyg0JfL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/81itQPVn-GL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/81t6Av5DvXL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/81MZRUuHJIL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/71zfaYItN8L._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/814ePfNubRL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/61QRgOgBx0L._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/81X85GWtYHL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/812YsUxpyfL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/61RBrScYUSL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/7198dM6Eu2L._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/51QlVfPCfkL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/81guvfQzeVL._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/81Prc5i7hML._AC_UY218_.jpg
# https://m.media-amazon.com/images/I/71C4pfJ7ecL._AC_UY218_.jpg
# ...

# %%
l=[]

for i in soup.find_all('a',class_='a-link-normal s-no-outline'):
    
    l.append('https://amazon.in'+i.get('href'))

# %%
url=l[0]

# %%
web=requests.get(url)

# %%
web
# Out:
# <Response [200]>

# %%
sou=bs4.BeautifulSoup(web.content,'html.parser')

# %%
sou.title.text.split('|')[0].strip()
# Out:
# 'Oppo F23 5G (Bold Gold, 8GB RAM, 256GB Storage)'

# %%
for i in sou.find_all('span',class_='celwidget'):
    print(i.text)
# Out:
#   135 answered questions

# %%
import pandas as pd
from pandasai import PandasAI

# Sample DataFrame
df = pd.DataFrame({
    "country": ["United States", "United Kingdom", "France", "Germany", "Italy", "Spain", "Canada", "Australia", "Japan", "China"],
    "gdp": [19294482071552, 2891615567872, 2411255037952, 3435817336832, 1745433788416, 1181205135360, 1607402389504, 1490967855104, 4380756541440, 14631844184064],
    "happiness_index": [6.94, 7.16, 6.66, 7.07, 6.38, 6.4, 7.23, 7.22, 5.87, 5.12]
})
df

# Instantiate a LLM
from pandasai.llm.openai import OpenAI

llm = OpenAI(api_token="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")

pandas_ai = PandasAI(llm, conversational=False)

# %%
pandas_ai.run( df,prompt='Which are the 5 happiest countries?')
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# c:\Users\Yogesh Yadav\Downloads\Python Learnings\Web Scrap.ipynb Cell 18 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Yogesh%20Yadav/Downloads/Python%20Learnings/Web%20Scrap.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> pandas_ai.run( df,prompt='Which are the 5 happiest countries?')
#
# File c:\Users\Yogesh Yadav\anaconda3\lib\site-packages\pandasai\__init__.py:127, in PandasAI.run(self, data_frame, prompt, is_conversational_answer, show_code, anonymize_df, use_error_correction_framework)
#     124 if anonymize_df:
#     125     df_head = anonymize_dataframe_head(df_head)
# --> 127 code = self._llm.generate_code(
#     128     self._task_instruction.format(
#     129         today_date=date.today(),
#     130         df_head=df_head,
#     131         num_rows=data_frame.shape[0],
# ...

# %%
df
# Out:
#           country             gdp  happiness_index
# 0   United States  19294482071552             6.94
# 1  United Kingdom   2891615567872             7.16
# 2          France   2411255037952             6.66
# 3         Germany   3435817336832             7.07
# 4           Italy   1745433788416             6.38
# 5           Spain   1181205135360             6.40
# 6          Canada   1607402389504             7.23
# 7       Australia   1490967855104             7.22
# 8           Japan   4380756541440             5.87
# 9           China  14631844184064             5.12

# %%
df[df['country']=='Italy']
# Out:
#   country            gdp  happiness_index
# 4   Italy  1745433788416             6.38

# %%
ab=df.sort_values(by=['happiness_index','gdp'],ascending=False,ignore_index=True)

# %%
ab.groupby
# Out:
#           country             gdp  happiness_index
# 0          Canada   1607402389504             7.23
# 1       Australia   1490967855104             7.22
# 2  United Kingdom   2891615567872             7.16
# 3         Germany   3435817336832             7.07
# 4   United States  19294482071552             6.94
# 5          France   2411255037952             6.66
# 6           Spain   1181205135360             6.40
# 7           Italy   1745433788416             6.38
# 8           Japan   4380756541440             5.87
# 9           China  14631844184064             5.12

# %%
import openai

openai.ChatCompletion.create(
  model="text-davinci-003",
  messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "The Los Angeles Dodgers won the World Series in 2020."},
        {"role": "user", "content": "Where was it played?"}
    ]
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# c:\Users\Yogesh Yadav\Downloads\Python Learnings\Web Scrap.ipynb Cell 23 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Yogesh%20Yadav/Downloads/Python%20Learnings/Web%20Scrap.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> import openai
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Yogesh%20Yadav/Downloads/Python%20Learnings/Web%20Scrap.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> openai.ChatCompletion.create(
#       <a href='vscode-notebook-cell:/c%3A/Users/Yogesh%20Yadav/Downloads/Python%20Learnings/Web%20Scrap.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a>   model="text-davinci-003",
#       <a href='vscode-notebook-cell:/c%3A/Users/Yogesh%20Yadav/Downloads/Python%20Learnings/Web%20Scrap.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a>   messages=[
# ...
