# %% [markdown]
# # All links from one page

# %%
import requests
from bs4 import BeautifulSoup
import urllib
# urllib.request.urlopen(url)
url='https://www.amazon.in/s?k=laptop&crid=2J7LCMD2BA4RR&sprefix=laptop%2Caps%2C298&ref=nb_sb_noss_1'
while True :
    link=requests.get(url,headers=({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}))
    if link.status_code==200:
        print(link)
        soup=BeautifulSoup(link.content,'html.parser')
        # soup
        se=set()
        xyz=soup.find_all('h2',{'class':'a-size-mini a-spacing-none a-color-base s-line-clamp-2'})
        for i in xyz:
            abc=i.find('a',{'class':"a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"})
            x=abc.get('href')
            se.add('https://amazon.in'+x)
        for i in se:
            print(i)  
        print(len(se))    
        break
# Out:
# <Response [200]>
# https://amazon.in/Acer-Business-Windows-Z8-415-Display/dp/B0C77GRX7J/ref=sr_1_12?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-12
# https://amazon.in/Honor-MagicBook-15-6-inch-Anti-Glare-Fingerprint/dp/B0BV6YHJMV/ref=sr_1_4?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-4
# https://amazon.in/Notebook-resolution-i5-11300H-15-6-inch-Fingerprint/dp/B098XK9BPC/ref=sr_1_16?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-16
# https://amazon.in/ASUS-Vivobook-Integrated-Fingerprint-X515MA-BR024WS/dp/B0C1GM4C6V/ref=sr_1_13?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-13
# https://amazon.in/HP-i5-1155G7-15-6-inch-Graphics-Speakers/dp/B0C3RDM59N/ref=sr_1_10?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-10
# https://amazon.in/ASUS-Vivobook-i3-1115G4-Transparent-X1400EA-EK322WS/dp/B0C3CNRQD1/ref=sr_1_7?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-7
# https://amazon.in/Dell-i5-1135G7-Rheinland-Certified-Comfortview/dp/B0C15BKF4G/ref=sr_1_11?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-11
# https://amazon.in/Dell-5-5500U-Rheinland-Certified-Comfortview/dp/B0C1434CCN/ref=sr_1_9?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-9
# https://amazon.in/ASUS-Vivobook-i5-12500H-Laptop-X1502ZA-EJ542WS/dp/B0C5Y3JBC4/ref=sr_1_15?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-15
# https://amazon.in/Lenovo-Celeron-1920x1080-Antiglare-82QYA00HIN/dp/B0C28GQ3YL/ref=sr_1_5?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-5
# https://amazon.in/HP-Celeron-Graphics-Speakers-15s-fq3071TU/dp/B0C3CLH1PV/ref=sr_1_6?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-6
# https://amazon.in/HP-i7-1255U-Graphics-Speakers-15s-fq5190TU/dp/B0C3D99LTP/ref=sr_1_8?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-8
# https://amazon.in/Honor-MagicBook-Anti-Glare-Fingerprint-NobelM-WFQ9AHNE/dp/B0BC9R8XYZ/ref=sr_1_14?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-14
# https://amazon.in/Acer-Business-Windows-Student-Z8-415/dp/B0C77J952V/ref=sr_1_1?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-1
# https://amazon.in/ASUS-Vivobook-14-inch-Windows-E1404FA-NK322WS/dp/B0BTWF2BQN/ref=sr_1_3?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-3
# https://amazon.in/ASUS-15-6-inch-Integrated-Transparent-X515MA-BR011W/dp/B09SGGB687/ref=sr_1_2?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687961592&sprefix=laptop%2Caps%2C298&sr=8-2
# 16

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup    
se=list(se)
se
df=pd.DataFrame()

def get_soup(url):
    user='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'
    while True:
      link=requests.get(url,headers={'User-Agent':user})
      if link.status_code==200:
        soup=BeautifulSoup(link.content,'html.parser') 
        break   
    return soup

# %% [markdown]
# # Dataframe from all link from page 1

# %%
z=0
import pandas as pd
df=pd.DataFrame()
while True:
    s=get_soup(se[z])
    try:
        a=[]
        b=[]
        data=s.find('table',{'class':'a-normal a-spacing-micro'})
        #print(data.text)
        for i ,y in zip(data.find_all('td',{'class':'a-span3'}),data.find_all('td',{'class':'a-span9'})):
            a.append(i.text)
            b.append(y.text)
        a.append('Price')
        b.append(s.find('span',{'class':"a-offscreen"}).text)    
        df1=pd.DataFrame([b],columns=[a])
        df=pd.concat([df,df1],axis=0,ignore_index=True)    
        z+=1
        if z==len(se):
            break   
    except:
        pass    
df
# Out:
#       Brand               Model Name         Screen Size
# 0      Acer              Acer one 14           14 Inches   \
# 1     Honor               BMH-WFQ9HN         15.6 Inches
# 2    Xiaomi              Mi Notebook         15.6 Inches
# 3      ASUS              Vivobook 15         15.6 Inches
# 4        HP             15s-fr4001TU    39.6 Centimetres
# 5      ASUS         Vivobook 14 2022           14 Inches
# 6      Dell              Vostro 3420           14 Inches
# 7      Dell              Vostro 3425           14 Inches
# 8      ASUS         ASUS Vivobook 15         15.6 Inches
# 9    Lenovo        Lenovo V15 G2 IJL         15.6 Inches
# 10       HP             15s-fq3071TU    39.6 Centimetres
# 11       HP             15s-fq5190TU    39.6 Centimetres
# 12    Honor               NMH-WFQ9HN           14 Inches
# 13     Acer              Acer one 14           14 Inches
# 14     ASUS    Vivobook Go 14 (2023)           14 Inches
# 15     ASUS       VivoBook 15 (2021)         15.6 Inches
#
#                  Colour            CPU Model   RAM Memory Installed Size
# 0                Silver              Core i5                        8 GB   \
# 1         Mystic Silver    AMD Ryzen 5 5500U                       16 GB
# 2                  Gray              Core i5                       16 GB
# 3    Transparent Silver              Celeron                        8 GB
# 4                Silver              Core i5                       16 GB
# 5    Transparent Silver              Core i3                        8 GB
# 6                 Black              Core i5                        8 GB
# 7          Carbon Black              Ryzen 5                        8 GB
# 8       Icelight Silver              Core i5                       16 GB
# 9                 Black              Celeron                        8 GB
# 10       Natural Silver              Celeron                        8 GB
# 11       Natural Silver              Core i7                       16 GB
# 12                 Gray    AMD Ryzen 5 5500U                       16 GB
# 13               Silver              Core i5                       16 GB
# 14          Mixed Black              Ryzen 3                        8 GB
# 15   Transparent Silver        Celeron N4020                        4 GB
#
#     Operating System                                    Special Feature
# 0    Windows 11 Home        Anti Glare Screen, Webcam, Memory Card Slot   \
# 1    Windows 11 Home    Fingerprint Reader, High Definition Audio, Tr...
# 2    Windows 11 Home    Backlift Keyboard, Fingerprint Sensor, Anti-g...
# 3    Windows 11 Home                                 Fingerprint Reader
# 4    Windows 11 Home    FHD, Backlit Keyboard, Micro-Edge Display, An...
# 5    Windows 11 Home                                 Anti Glare Coating
# 6    Windows 11 Home                                                 NaN
# 7    Windows 11 Home                                               Thin
# 8    Windows 11 Home                                   Backlit Keyboard
# 9                DOS                                               Thin
# 10   Windows 11 Home    Brightview, HD, Micro-Edge Display, Numeric K...
# 11   Windows 11 Home    FHD, UWVA, Micro-Edge Display, Anti-Glare, Nu...
# 12   Windows 11 Home    Backlit Keyboard, Anti Glare Screen, Fingerpr...
# 13   Windows 11 Home        Anti Glare Screen, Webcam, Memory Card Slot
# 14   Windows 11 Home                                 Anti Glare Coating
# 15   Windows 11 Home    Fingerprint Reader, Backlit Keyboard, Anti Gl...
#
#     Graphics Card Description      Graphics Coprocessor   Hard Disk Size
# 0                  Integrated    Intel Iris Xe Graphics               NaN
# 1                  Integrated                        NaN          512 GB
# 2                  Integrated                        NaN          512 GB
# 3                  Integrated                        NaN          512 GB
# 4                  Integrated                        NaN          512 GB
# 5                  Integrated                        NaN          512 GB
# 6                  Integrated                INTEGRATED           512 GB
# 7                  Integrated                        NaN          512 GB
# 8                  Integrated                        NaN          512 GB
# 9                  Integrated                        NaN          256 GB
# 10                 Integrated                        NaN          512 GB
# 11                 Integrated                        NaN          512 GB
# 12                 Integrated                        NaN          512 GB
# 13                 Integrated    Intel Iris Xe Graphics               NaN
# 14                 Integrated                        NaN          512 GB
# 15                 Integrated                        NaN          512 GB

# %% [markdown]
# # From Every Pages  combining into one

# %%
url='https://www.amazon.in/s?k=laptop&crid=2J7LCMD2BA4RR&sprefix=laptop%2Caps%2C298&ref=nb_sb_noss_1'
c=0
v=1
links=set()
import pandas as pd
df=pd.DataFrame()
while True:
    try:
      soup=get_soup(url)
      next_link=soup.find('a',{'class':'s-pagination-item s-pagination-next s-pagination-button s-pagination-separator'}).get('href')
      links.add(url)
      print(url)
      if next_link is not None:
        url='https://amazon.in'+next_link

        c+=1
        print('Link : ',c)
        se=set()
        xyz=soup.find_all('h2',{'class':'a-size-mini a-spacing-none a-color-base s-line-clamp-2'})
        for j in xyz:
          abc=j.find('a',{'class':"a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"}).get('href')
          se.add('https://amazon.in'+abc)
        se=list(se)
        print(len(se))
        z=0
        while True:
            s=get_soup(se[z])
            try:
                a=[]
                b=[]
                data=s.find('table',{'class':'a-normal a-spacing-micro'})
                #print(data.text)
                for i ,y in zip(data.find_all('td',{'class':'a-span3'}),data.find_all('td',{'class':'a-span9'})):
                    a.append(i.text)
                    b.append(y.text)
                a.append('Price')
                b.append(s.find('span',{'class':"a-offscreen"}).text)    
                df1=pd.DataFrame([b],columns=[a])
                df=pd.concat([df,df1],axis=0,ignore_index=True)    
                z+=1
                if z==len(se):
                    break   
            except:
                pass    

    except:
        pass

    if c==19:
      break
    v+=1
df    
df.to_excel('Data.xlsx',index=False)
