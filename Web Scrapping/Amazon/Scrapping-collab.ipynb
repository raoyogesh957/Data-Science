# %%
import requests
from bs4 import BeautifulSoup
import urllib

def get_soup(url):
    user='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'
    while True:
      link=requests.get(url,headers={'User-Agent':user})
      if link.status_code==200:
        soup=BeautifulSoup(link.content,'html.parser')
        break
    return soup

# %%
url='https://www.amazon.in/s?k=laptop&crid=2J7LCMD2BA4RR&sprefix=laptop%2Caps%2C298&ref=nb_sb_noss_1'
c=0
v=1
links=set()
import pandas as pd
df=pd.DataFrame()
while True:
    try:
      soup=get_soup(url)
      next_link=soup.find('a',{'class':'s-pagination-item s-pagination-next s-pagination-button s-pagination-separator'}).get('href')
      links.add(url)
      print(url)
      if next_link is not None:
        url='https://amazon.in'+next_link

        c+=1
        print('Link : ',c)
        se=set()
        xyz=soup.find_all('h2',{'class':'a-size-mini a-spacing-none a-color-base s-line-clamp-2'})
        for j in xyz:
          abc=j.find('a',{'class':"a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"}).get('href')
          se.add('https://amazon.in'+abc)
        se=list(se)
        print(len(se))
        z=0
        while True:
            s=get_soup(se[z])
            try:
                a=[]
                b=[]
                data=s.find('table',{'class':'a-normal a-spacing-micro'})
                #print(data.text)
                for i ,y in zip(data.find_all('td',{'class':'a-span3'}),data.find_all('td',{'class':'a-span9'})):
                    a.append(i.text)
                    b.append(y.text)
                a.append('Price')
                b.append(s.find('span',{'class':"a-offscreen"}).text)
                df1=pd.DataFrame([b],columns=[a])
                df=pd.concat([df,df1],axis=0,ignore_index=True)
                z+=1
                if z==len(se):
                    break
            except:
                pass

    except:
        pass

    if c==19:
      break
    v+=1
df
df.to_excel('Data.xlsx',index=False)
# Out:
# https://www.amazon.in/s?k=laptop&crid=2J7LCMD2BA4RR&sprefix=laptop%2Caps%2C298&ref=nb_sb_noss_1
# Link :  1
# 16
# https://amazon.in/s?k=laptop&page=2&crid=2J7LCMD2BA4RR&qid=1687967718&sprefix=laptop%2Caps%2C298&ref=sr_pg_1
# Link :  2
# 16
# https://amazon.in/s?k=laptop&page=3&crid=2J7LCMD2BA4RR&qid=1687967805&sprefix=laptop%2Caps%2C298&ref=sr_pg_2
# Link :  3
# 16
# https://amazon.in/s?k=laptop&page=4&crid=2J7LCMD2BA4RR&qid=1687967902&sprefix=laptop%2Caps%2C298&ref=sr_pg_3
# Link :  4
# 16
# https://amazon.in/s?k=laptop&page=5&crid=2J7LCMD2BA4RR&qid=1687967984&sprefix=laptop%2Caps%2C298&ref=sr_pg_4
# Link :  5
# 16
# https://amazon.in/s?k=laptop&page=6&crid=2J7LCMD2BA4RR&qid=1687968082&sprefix=laptop%2Caps%2C298&ref=sr_pg_5
# Link :  6
# 16
# https://amazon.in/s?k=laptop&page=7&crid=2J7LCMD2BA4RR&qid=1687968220&sprefix=laptop%2Caps%2C298&ref=sr_pg_6
# Link :  7
# 16
# https://amazon.in/s?k=laptop&page=8&crid=2J7LCMD2BA4RR&qid=1687968363&sprefix=laptop%2Caps%2C298&ref=sr_pg_7
# Link :  8
# 16
# https://amazon.in/s?k=laptop&page=9&crid=2J7LCMD2BA4RR&qid=1687968512&sprefix=laptop%2Caps%2C298&ref=sr_pg_8
# Link :  9
# 16
# https://amazon.in/s?k=laptop&page=10&crid=2J7LCMD2BA4RR&qid=1687968714&sprefix=laptop%2Caps%2C298&ref=sr_pg_9
# Link :  10
# 16
# https://amazon.in/s?k=laptop&page=11&crid=2J7LCMD2BA4RR&qid=1687968932&sprefix=laptop%2Caps%2C298&ref=sr_pg_10
# Link :  11
# 16
# https://amazon.in/s?k=laptop&page=12&crid=2J7LCMD2BA4RR&qid=1687969133&sprefix=laptop%2Caps%2C298&ref=sr_pg_11
# Link :  12
# 16
# https://amazon.in/s?k=laptop&page=13&crid=2J7LCMD2BA4RR&qid=1687969360&sprefix=laptop%2Caps%2C298&ref=sr_pg_12
# Link :  13
# 16
# https://amazon.in/s?k=laptop&page=14&crid=2J7LCMD2BA4RR&qid=1687969561&sprefix=laptop%2Caps%2C298&ref=sr_pg_13
# Link :  14
# 16
# https://amazon.in/s?k=laptop&page=15&crid=2J7LCMD2BA4RR&qid=1687969901&sprefix=laptop%2Caps%2C298&ref=sr_pg_14
# Link :  15
# 16
# https://amazon.in/s?k=laptop&page=16&crid=2J7LCMD2BA4RR&qid=1687970155&sprefix=laptop%2Caps%2C298&ref=sr_pg_15
# Link :  16
# 16
# https://amazon.in/s?k=laptop&page=17&crid=2J7LCMD2BA4RR&qid=1687970275&sprefix=laptop%2Caps%2C298&ref=sr_pg_16
# Link :  17
# 16
# https://amazon.in/s?k=laptop&page=18&crid=2J7LCMD2BA4RR&qid=1687970388&sprefix=laptop%2Caps%2C298&ref=sr_pg_17
# Link :  18
# 16
# https://amazon.in/s?k=laptop&page=19&crid=2J7LCMD2BA4RR&qid=1687970497&sprefix=laptop%2Caps%2C298&ref=sr_pg_18
# Link :  19
# 16

# %%
# import pandas as pd
# df=pd.DataFrame()
# z=0
# se=['https://amazon.in/Honor-MagicBook-Anti-Glare-Fingerprint-NobelM-WFQ9AHNE/dp/B0BC9R8XYZ/ref=sr_1_12?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687956085&sprefix=laptop%2Caps%2C298&sr=8-12','https://amazon.in/Acer-Extensa-Processor-Graphics-EX215-33/dp/B0BXL9KVCL/ref=sr_1_7?crid=2J7LCMD2BA4RR&keywords=laptop&qid=1687956085&sprefix=laptop%2Caps%2C298&sr=8-7']
# while True:
#   try:
#       brand=[]
#       series=[]
#       RAM=[]
#       price=[]
#       url=se[z]
#       print(url)
#       while True:
#         content=requests.get(url,headers=({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}))
#         if content.status_code==200:
#           break
#       print(content.status_code)
#       soup=BeautifulSoup(content.content,'html.parser')
#       p=soup.find('span',{'class':'a-price-whole'}).text
#       print(p)
#       price.append(p)
#       data=soup.find('table',{'class':'productDetails_techSpec_section_1'})
#       print(data)
#       # for i in data.find_all('table',{'class':"a-keyvalue prodDetTable",'id':'productDetails_techSpec_section_1'}):
#       #   print(i)
#       for j ,x in zip(data.find_all('th'),data.find_all('td')):
#           if j.text.strip()=='Brand':
#               print('Brand : ',x.text.strip())
#               brand.append(x.text.strip())
#           elif  j.text.strip()=='Series':
#               print('Series : ',x.text.strip())
#               series.append(x.text.strip())
#           elif  j.text.strip()=='RAM Size':
#               print('RAM : ',x.text.strip())
#               RAM.append(x.text.strip())

#       df1=pd.DataFrame({'Brand':brand,'Series':series,'RAM':RAM,'Price':price},index=[0])
#       df=pd.concat([df,df1],axis=0,ignore_index=True)
#       z+=1
#       if z==1:
#         break
#   except:
#     pass
# df
